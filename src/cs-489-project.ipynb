# %%
# !cp /kaggle/input/datasets/madhuvsharma1203/interstellar-autocomplete/myprogram.py .
# !cp /kaggle/input/datasets/madhuvsharma1203/interstellar-autocomplete/grade.py .
# !cp -rf /kaggle/input/datasets/madhuvsharma1203/space-data .

# %%
# !python ./myprogram.py train --train_dir ./space-data --work_dir ./work --resume_model "/kaggle/input/datasets/madhuvsharma1203/interstellar-model/model v43.pt" --resume_state "/kaggle/input/datasets/madhuvsharma1203/interstellar-model/model v43.train_state.pt" --extra_epochs 8

# %%
# !cp -rf /kaggle/input/datasets/madhuvsharma1203/cs-489-competition-kaggle-data ./

# %%
# !python ./myprogram.py test --test_data ./cs-489-competition-kaggle-data/input.txt --work_dir ./work --test_output ./my-pred.txt

# %%
# !python ./myprogram.py test --test_data ./cs-489-competition-kaggle-data/test.csv --work_dir ./work --test_output ./submission.csv

# %%
# !python ./grade.py ./my-pred.txt ./cs-489-competition-kaggle-data/answer.txt

# %%
# !kaggle competitions submit -c u-waterloo-cs-498-intro-to-nlp-project -f ./submission.csv -m "latest run"
